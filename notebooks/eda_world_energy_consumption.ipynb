# %% [markdown]
# # Exploratory Data Analysis: World Energy Consumption
# This notebook performs basic EDA on the World Energy Consumption dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('../datasets/1_energy_consumption/World Energy Consumption.csv')
df.head()

# %%
df.info()

# %%
df.describe()
