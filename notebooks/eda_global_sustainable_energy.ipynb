# %% [markdown]
# # Exploratory Data Analysis: Global Data on Sustainable Energy
# This notebook performs basic EDA on the global sustainable energy dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('../datasets/3_carbon_emission_and_sustainable_energy/global-data-on-sustainable-energy (1).csv')
df.head()

# %%
df.info()

# %%
df.describe()
