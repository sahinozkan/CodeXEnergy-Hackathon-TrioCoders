# %% [markdown]
# # Exploratory Data Analysis: Renewable Energy
# This notebook performs basic EDA on the renewable energy dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('../datasets/2_renewable_energy/renewable_energy.csv')
df.head()

# %%
df.info()

# %%
df.describe()
